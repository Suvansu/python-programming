# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\suvan\Documents\sem 1\Big Data Fund\bankinfo.csv", sep=';')

# %%
print(df.describe())
# Out:
#               age       balance         day     duration    campaign  \
# count  111.000000    111.000000  111.000000   111.000000  111.000000
# mean    40.972973   1600.018018   15.315315   277.225225    2.099099
# std     11.161182   2766.392012    7.893590   243.466618    1.920961
# min     20.000000   -849.000000    1.000000     9.000000    1.000000
# 25%     32.500000    175.500000    8.000000   134.000000    1.000000
# 50%     38.000000    493.000000   14.000000   220.000000    2.000000
# 75%     49.000000   1821.000000   20.500000   343.000000    2.000000
# max     78.000000  16873.000000   30.000000  1740.000000   18.000000
#
#             pdays    previous
# count  111.000000  111.000000
# mean    43.117117    0.657658
# std     98.606448    2.180473
# min     -1.000000    0.000000
# 25%     -1.000000    0.000000
# 50%     -1.000000    0.000000
# 75%     -1.000000    0.000000
# max    460.000000   20.000000

# %%
df['age'].hist(bins=10)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
print("Hello World, I am running this in JN")
# Out:
# Hello World, I am running this in JN
