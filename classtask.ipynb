# %%
str_one = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
print(str_one.lower())
# Out:
# abcdefghijklmnopqrstuvwxyz

# %%
str_name = "My name is Suvansu"
print(len(str_name))
print("slicing the variable" , str_name[0:5])
# Out:
# 18
# slicing the variable My na

# %%
str_surname = "Paudel"

print(f"My name is Suvansu {str_surname}")
